# %%
# !./run_eval_vis_AVD.sh
# Out:
# AVD_Home_011_1_traj1, ate: 51.366516461495664
# GLFW Error: GLX: No GLXFBConfigs returned
# GLFW Error: GLX: Failed to find a suitable GLXFBConfig
# Failed to create window
# [DrawGeometries] Failed creating OpenGL window.

# %%
# !./lstm_run_train_AVD.sh 1
# Out:
# Namespace(batch_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_004_1', gpu='1', latent_size=16, log_interval=8, loss='bce_ch', lr=0.001, mode='single', model=None, n_epochs=15000, n_samples=35, name='AVD_Home_004_1_traj1', scene_index=1, subsample_rate=40, traj='traj1.txt')
# loading dataset
# 16
# pccppcpc1123 (16, 27, 48, 3)
# creating model
# start training
# start Parameter containing:
# tensor([ 0.3124,  1.0227, -0.1865, -0.7689,  0.4419,  1.2796,  0.2077,  0.5042,
#         -0.0190,  0.0870, -0.0606, -0.4929,  0.0135, -0.4370, -0.0180,  0.3459],
#        device='cuda:0', requires_grad=True)
# None
# end Parameter containing:
# tensor([ 0.3166,  1.0186, -0.1823, -0.7647,  0.4461,  1.2838,  0.2035,  0.5000,
#         -0.0231,  0.0912, -0.0644, -0.4887,  0.0093, -0.4328, -0.0139,  0.3501],
#        device='cuda:0', requires_grad=True)
# start tensor([ 0.3166,  1.0186, -0.1823, -0.7647,  0.4461,  1.2838,  0.2035,  0.5000,
#         -0.0231,  0.0912, -0.0644, -0.4887,  0.0093, -0.4328, -0.0139,  0.3501],
#        device='cuda:0')
# None
# end tensor([ 0.3194,  1.0158, -0.1795, -0.7619,  0.4489,  1.2866,  0.2008,  0.4972,
#         -0.0259,  0.0940, -0.0669, -0.4859,  0.0065, -0.4300, -0.0110,  0.3529],
#        device='cuda:0')
# start tensor([ 0.3194,  1.0158, -0.1795, -0.7619,  0.4489,  1.2866,  0.2008,  0.4972,
#         -0.0259,  0.0940, -0.0669, -0.4859,  0.0065, -0.4300, -0.0110,  0.3529],
#        device='cuda:0')
# None
# end tensor([ 0.3216,  1.0136, -0.1773, -0.7597,  0.4510,  1.2888,  0.1986,  0.4950,
#         -0.0280,  0.0962, -0.0689, -0.4837,  0.0043, -0.4278, -0.0089,  0.3551],
#        device='cuda:0')
# start tensor([ 0.3216,  1.0136, -0.1773, -0.7597,  0.4510,  1.2888,  0.1986,  0.4950,
#         -0.0280,  0.0962, -0.0689, -0.4837,  0.0043, -0.4278, -0.0089,  0.3551],
#        device='cuda:0')
# None
# end tensor([ 0.3234,  1.0118, -0.1756, -0.7580,  0.4528,  1.2905,  0.1968,  0.4933,
#         -0.0297,  0.0979, -0.0705, -0.4819,  0.0025, -0.4260, -0.0071,  0.3569],
#        device='cuda:0')
# start tensor([ 0.3234,  1.0118, -0.1756, -0.7580,  0.4528,  1.2905,  0.1968,  0.4933,
#         -0.0297,  0.0979, -0.0705, -0.4819,  0.0025, -0.4260, -0.0071,  0.3569],
#        device='cuda:0')
# None
# end tensor([ 0.3249,  1.0103, -0.1740, -0.7565,  0.4543,  1.2920,  0.1954,  0.4918,
#         -0.0312,  0.0994, -0.0718, -0.4804,  0.0010, -0.4245, -0.0056,  0.3584],
#        device='cuda:0')
# start tensor([ 0.3249,  1.0103, -0.1740, -0.7565,  0.4543,  1.2920,  0.1954,  0.4918,
#         -0.0312,  0.0994, -0.0718, -0.4804,  0.0010, -0.4245, -0.0056,  0.3584],
#        device='cuda:0')
# None
# end tensor([ 0.3262,  1.0090, -0.1727, -0.7552,  0.4556,  1.2933,  0.1941,  0.4905,
#         -0.0325,  0.1007, -0.0730, -0.4791, -0.0003, -0.4232, -0.0043,  0.3597],
#        device='cuda:0')
# start tensor([ 0.3262,  1.0090, -0.1727, -0.7552,  0.4556,  1.2933,  0.1941,  0.4905,
#         -0.0325,  0.1007, -0.0730, -0.4791, -0.0003, -0.4232, -0.0043,  0.3597],
#        device='cuda:0')
# None
# end tensor([ 0.3273,  1.0079, -0.1716, -0.7540,  0.4567,  1.2945,  0.1930,  0.4893,
#         -0.0336,  0.1019, -0.0740, -0.4780, -0.0014, -0.4221, -0.0032,  0.3608],
#        device='cuda:0')
# start tensor([ 0.3273,  1.0079, -0.1716, -0.7540,  0.4567,  1.2945,  0.1930,  0.4893,
#         -0.0336,  0.1019, -0.0740, -0.4780, -0.0014, -0.4221, -0.0032,  0.3608],
#        device='cuda:0')
# None
# end tensor([ 0.3283,  1.0069, -0.1706, -0.7530,  0.4577,  1.2955,  0.1920,  0.4883,
#         -0.0346,  0.1029, -0.0749, -0.4770, -0.0024, -0.4211, -0.0022,  0.3618],
#        device='cuda:0')
# [8/15000], training loss: 0.1370
# start tensor([ 0.3283,  1.0069, -0.1706, -0.7530,  0.4577,  1.2955,  0.1920,  0.4883,
#         -0.0346,  0.1029, -0.0749, -0.4770, -0.0024, -0.4211, -0.0022,  0.3618],
#        device='cuda:0')
# None
# end tensor([ 0.3292,  1.0060, -0.1697, -0.7522,  0.4586,  1.2963,  0.1911,  0.4875,
#         -0.0355,  0.1038, -0.0757, -0.4761, -0.0033, -0.4202, -0.0013,  0.3627],
#        device='cuda:0')
# start tensor([ 0.3292,  1.0060, -0.1697, -0.7522,  0.4586,  1.2963,  0.1911,  0.4875,
#         -0.0355,  0.1038, -0.0757, -0.4761, -0.0033, -0.4202, -0.0013,  0.3627],
#        device='cuda:0')
# None
# end tensor([ 0.3300,  1.0052, -0.1689, -0.7514,  0.4594,  1.2971,  0.1903,  0.4867,
#         -0.0363,  0.1046, -0.0764, -0.4753, -0.0041, -0.4194, -0.0005,  0.3635],
#        device='cuda:0')
# start tensor([ 0.3300,  1.0052, -0.1689, -0.7514,  0.4594,  1.2971,  0.1903,  0.4867,
#         -0.0363,  0.1046, -0.0764, -0.4753, -0.0041, -0.4194, -0.0005,  0.3635],
#        device='cuda:0')
# None
# end tensor([ 0.3307,  1.0045, -0.1682, -0.7507,  0.4601,  1.2978,  0.1896,  0.4860,
#         -0.0370,  0.1053, -0.0770, -0.4746, -0.0048, -0.4187,  0.0002,  0.3642],
#        device='cuda:0')
# start tensor([ 0.3307,  1.0045, -0.1682, -0.7507,  0.4601,  1.2978,  0.1896,  0.4860,
#         -0.0370,  0.1053, -0.0770, -0.4746, -0.0048, -0.4187,  0.0002,  0.3642],
#        device='cuda:0')
# None
# end tensor([ 0.3313,  1.0039, -0.1676, -0.7500,  0.4607,  1.2985,  0.1890,  0.4853,
#         -0.0376,  0.1059, -0.0776, -0.4740, -0.0054, -0.4180,  0.0009,  0.3648],
#        device='cuda:0')
# start tensor([ 0.3313,  1.0039, -0.1676, -0.7500,  0.4607,  1.2985,  0.1890,  0.4853,
#         -0.0376,  0.1059, -0.0776, -0.4740, -0.0054, -0.4180,  0.0009,  0.3648],
#        device='cuda:0')
# None
# end tensor([ 0.3319,  1.0033, -0.1670, -0.7495,  0.4613,  1.2991,  0.1884,  0.4847,
#         -0.0381,  0.1065, -0.0781, -0.4734, -0.0060, -0.4175,  0.0014,  0.3654],
#        device='cuda:0')
# start tensor([ 0.3319,  1.0033, -0.1670, -0.7495,  0.4613,  1.2991,  0.1884,  0.4847,
#         -0.0381,  0.1065, -0.0781, -0.4734, -0.0060, -0.4175,  0.0014,  0.3654],
#        device='cuda:0')
# None
# end tensor([ 0.3324,  1.0028, -0.1665, -0.7489,  0.4618,  1.2996,  0.1879,  0.4842,
#         -0.0387,  0.1070, -0.0786, -0.4729, -0.0065, -0.4169,  0.0019,  0.3659],
#        device='cuda:0')
# start tensor([ 0.3324,  1.0028, -0.1665, -0.7489,  0.4618,  1.2996,  0.1879,  0.4842,
#         -0.0387,  0.1070, -0.0786, -0.4729, -0.0065, -0.4169,  0.0019,  0.3659],
#        device='cuda:0')
# None
# end tensor([ 0.3329,  1.0023, -0.1660, -0.7485,  0.4622,  1.3000,  0.1874,  0.4838,
#         -0.0391,  0.1075, -0.0790, -0.4724, -0.0070, -0.4165,  0.0024,  0.3664],
#        device='cuda:0')
# start tensor([ 0.3329,  1.0023, -0.1660, -0.7485,  0.4622,  1.3000,  0.1874,  0.4838,
#         -0.0391,  0.1075, -0.0790, -0.4724, -0.0070, -0.4165,  0.0024,  0.3664],
#        device='cuda:0')
# None
# end tensor([ 0.3333,  1.0019, -0.1656, -0.7480,  0.4627,  1.3005,  0.1870,  0.4833,
#         -0.0395,  0.1079, -0.0794, -0.4720, -0.0074, -0.4161,  0.0028,  0.3668],
#        device='cuda:0')
# [16/15000], training loss: 0.1163
# start tensor([ 0.3333,  1.0019, -0.1656, -0.7480,  0.4627,  1.3005,  0.1870,  0.4833,
#         -0.0395,  0.1079, -0.0794, -0.4720, -0.0074, -0.4161,  0.0028,  0.3668],
#        device='cuda:0')
# None
# end tensor([ 0.3337,  1.0015, -0.1652, -0.7477,  0.4631,  1.3009,  0.1866,  0.4829,
#         -0.0399,  0.1083, -0.0797, -0.4716, -0.0078, -0.4157,  0.0032,  0.3672],
#        device='cuda:0')
# start tensor([ 0.3337,  1.0015, -0.1652, -0.7477,  0.4631,  1.3009,  0.1866,  0.4829,
#         -0.0399,  0.1083, -0.0797, -0.4716, -0.0078, -0.4157,  0.0032,  0.3672],
#        device='cuda:0')
# None
# end tensor([ 0.3340,  1.0012, -0.1649, -0.7473,  0.4634,  1.3012,  0.1863,  0.4826,
#         -0.0403,  0.1086, -0.0801, -0.4713, -0.0082, -0.4153,  0.0036,  0.3675],
#        device='cuda:0')
# start tensor([ 0.3340,  1.0012, -0.1649, -0.7473,  0.4634,  1.3012,  0.1863,  0.4826,
#         -0.0403,  0.1086, -0.0801, -0.4713, -0.0082, -0.4153,  0.0036,  0.3675],
#        device='cuda:0')
# None
# end tensor([ 0.3343,  1.0009, -0.1645, -0.7470,  0.4637,  1.3015,  0.1860,  0.4823,
#         -0.0406,  0.1089, -0.0803, -0.4710, -0.0085, -0.4150,  0.0039,  0.3679],
#        device='cuda:0')
# start tensor([ 0.3343,  1.0009, -0.1645, -0.7470,  0.4637,  1.3015,  0.1860,  0.4823,
#         -0.0406,  0.1089, -0.0803, -0.4710, -0.0085, -0.4150,  0.0039,  0.3679],
#        device='cuda:0')
# None
# end tensor([ 0.3346,  1.0006, -0.1643, -0.7467,  0.4640,  1.3018,  0.1857,  0.4820,
#         -0.0409,  0.1092, -0.0806, -0.4707, -0.0088, -0.4147,  0.0042,  0.3681],
#        device='cuda:0')
# start tensor([ 0.3346,  1.0006, -0.1643, -0.7467,  0.4640,  1.3018,  0.1857,  0.4820,
#         -0.0409,  0.1092, -0.0806, -0.4707, -0.0088, -0.4147,  0.0042,  0.3681],
#        device='cuda:0')
# None
# end tensor([ 0.3349,  1.0003, -0.1640, -0.7464,  0.4643,  1.3021,  0.1854,  0.4817,
#         -0.0411,  0.1095, -0.0808, -0.4704, -0.0090, -0.4144,  0.0045,  0.3684],
#        device='cuda:0')
# start tensor([ 0.3349,  1.0003, -0.1640, -0.7464,  0.4643,  1.3021,  0.1854,  0.4817,
#         -0.0411,  0.1095, -0.0808, -0.4704, -0.0090, -0.4144,  0.0045,  0.3684],
#        device='cuda:0')
# None
# end tensor([ 0.3351,  1.0001, -0.1638, -0.7462,  0.4645,  1.3023,  0.1852,  0.4815,
#         -0.0414,  0.1097, -0.0811, -0.4702, -0.0093, -0.4142,  0.0047,  0.3686],
#        device='cuda:0')
# start tensor([ 0.3351,  1.0001, -0.1638, -0.7462,  0.4645,  1.3023,  0.1852,  0.4815,
#         -0.0414,  0.1097, -0.0811, -0.4702, -0.0093, -0.4142,  0.0047,  0.3686],
#        device='cuda:0')
# None
# end tensor([ 0.3354,  0.9999, -0.1635, -0.7460,  0.4647,  1.3025,  0.1850,  0.4813,
#         -0.0416,  0.1100, -0.0812, -0.4700, -0.0095, -0.4140,  0.0049,  0.3689],
#        device='cuda:0')
# start tensor([ 0.3354,  0.9999, -0.1635, -0.7460,  0.4647,  1.3025,  0.1850,  0.4813,
#         -0.0416,  0.1100, -0.0812, -0.4700, -0.0095, -0.4140,  0.0049,  0.3689],
#        device='cuda:0')
# None
# end tensor([ 0.3356,  0.9997, -0.1633, -0.7458,  0.4649,  1.3027,  0.1848,  0.4811,
#         -0.0418,  0.1102, -0.0814, -0.4698, -0.0097, -0.4138,  0.0051,  0.3691],
#        device='cuda:0')
# [24/15000], training loss: 0.1251
# start tensor([ 0.3356,  0.9997, -0.1633, -0.7458,  0.4649,  1.3027,  0.1848,  0.4811,
#         -0.0418,  0.1102, -0.0814, -0.4698, -0.0097, -0.4138,  0.0051,  0.3691],
#        device='cuda:0')
# None
# end tensor([ 0.3357,  0.9995, -0.1632, -0.7456,  0.4651,  1.3029,  0.1846,  0.4809,
#         -0.0419,  0.1103, -0.0816, -0.4696, -0.0099, -0.4136,  0.0053,  0.3692],
#        device='cuda:0')
# start tensor([ 0.3357,  0.9995, -0.1632, -0.7456,  0.4651,  1.3029,  0.1846,  0.4809,
#         -0.0419,  0.1103, -0.0816, -0.4696, -0.0099, -0.4136,  0.0053,  0.3692],
#        device='cuda:0')
# None
# end tensor([ 0.3359,  0.9993, -0.1630, -0.7454,  0.4653,  1.3031,  0.1844,  0.4807,
#         -0.0421,  0.1105, -0.0817, -0.4694, -0.0100, -0.4134,  0.0055,  0.3694],
#        device='cuda:0')
# start tensor([ 0.3359,  0.9993, -0.1630, -0.7454,  0.4653,  1.3031,  0.1844,  0.4807,
#         -0.0421,  0.1105, -0.0817, -0.4694, -0.0100, -0.4134,  0.0055,  0.3694],
#        device='cuda:0')
# None
# end tensor([ 0.3361,  0.9992, -0.1628, -0.7453,  0.4654,  1.3032,  0.1843,  0.4806,
#         -0.0423,  0.1107, -0.0819, -0.4693, -0.0102, -0.4133,  0.0056,  0.3696],
#        device='cuda:0')
# start tensor([ 0.3361,  0.9992, -0.1628, -0.7453,  0.4654,  1.3032,  0.1843,  0.4806,
#         -0.0423,  0.1107, -0.0819, -0.4693, -0.0102, -0.4133,  0.0056,  0.3696],
#        device='cuda:0')
# None
# end tensor([ 0.3362,  0.9990, -0.1627, -0.7451,  0.4656,  1.3034,  0.1841,  0.4804,
#         -0.0424,  0.1108, -0.0820, -0.4691, -0.0103, -0.4131,  0.0057,  0.3697],
#        device='cuda:0')
# start tensor([ 0.3362,  0.9990, -0.1627, -0.7451,  0.4656,  1.3034,  0.1841,  0.4804,
#         -0.0424,  0.1108, -0.0820, -0.4691, -0.0103, -0.4131,  0.0057,  0.3697],
#        device='cuda:0')
# None
# end tensor([ 0.3363,  0.9989, -0.1626, -0.7450,  0.4657,  1.3035,  0.1840,  0.4803,
#         -0.0425,  0.1109, -0.0821, -0.4690, -0.0104, -0.4130,  0.0059,  0.3698],
#        device='cuda:0')
# start tensor([ 0.3363,  0.9989, -0.1626, -0.7450,  0.4657,  1.3035,  0.1840,  0.4803,
#         -0.0425,  0.1109, -0.0821, -0.4690, -0.0104, -0.4130,  0.0059,  0.3698],
#        device='cuda:0')
# None
# end tensor([ 0.3364,  0.9988, -0.1625, -0.7449,  0.4658,  1.3036,  0.1839,  0.4802,
#         -0.0426,  0.1110, -0.0822, -0.4689, -0.0106, -0.4129,  0.0060,  0.3699],
#        device='cuda:0')
# start tensor([ 0.3364,  0.9988, -0.1625, -0.7449,  0.4658,  1.3036,  0.1839,  0.4802,
#         -0.0426,  0.1110, -0.0822, -0.4689, -0.0106, -0.4129,  0.0060,  0.3699],
#        device='cuda:0')
# None
# end tensor([ 0.3365,  0.9987, -0.1624, -0.7448,  0.4659,  1.3037,  0.1838,  0.4801,
#         -0.0427,  0.1111, -0.0823, -0.4688, -0.0107, -0.4128,  0.0061,  0.3700],
#        device='cuda:0')
# start tensor([ 0.3365,  0.9987, -0.1624, -0.7448,  0.4659,  1.3037,  0.1838,  0.4801,
#         -0.0427,  0.1111, -0.0823, -0.4688, -0.0107, -0.4128,  0.0061,  0.3700],
#        device='cuda:0')
# None
# end tensor([ 0.3366,  0.9986, -0.1623, -0.7447,  0.4660,  1.3038,  0.1837,  0.4800,
#         -0.0428,  0.1112, -0.0824, -0.4687, -0.0108, -0.4127,  0.0062,  0.3701],
#        device='cuda:0')
# [32/15000], training loss: 0.1107
# start tensor([ 0.3366,  0.9986, -0.1623, -0.7447,  0.4660,  1.3038,  0.1837,  0.4800,
#         -0.0428,  0.1112, -0.0824, -0.4687, -0.0108, -0.4127,  0.0062,  0.3701],
#        device='cuda:0')
# None
# end tensor([ 0.3367,  0.9985, -0.1622, -0.7446,  0.4661,  1.3039,  0.1836,  0.4799,
#         -0.0429,  0.1113, -0.0825, -0.4686, -0.0108, -0.4126,  0.0063,  0.3702],
#        device='cuda:0')
# start tensor([ 0.3367,  0.9985, -0.1622, -0.7446,  0.4661,  1.3039,  0.1836,  0.4799,
#         -0.0429,  0.1113, -0.0825, -0.4686, -0.0108, -0.4126,  0.0063,  0.3702],
#        device='cuda:0')
# None
# end tensor([ 0.3368,  0.9984, -0.1621, -0.7446,  0.4662,  1.3040,  0.1835,  0.4798,
#         -0.0430,  0.1114, -0.0825, -0.4685, -0.0109, -0.4125,  0.0063,  0.3703],
#        device='cuda:0')
# start tensor([ 0.3368,  0.9984, -0.1621, -0.7446,  0.4662,  1.3040,  0.1835,  0.4798,
#         -0.0430,  0.1114, -0.0825, -0.4685, -0.0109, -0.4125,  0.0063,  0.3703],
#        device='cuda:0')
# None
# end tensor([ 0.3369,  0.9984, -0.1620, -0.7445,  0.4662,  1.3040,  0.1835,  0.4798,
#         -0.0431,  0.1115, -0.0826, -0.4685, -0.0110, -0.4125,  0.0064,  0.3704],
#        device='cuda:0')
# start tensor([ 0.3369,  0.9984, -0.1620, -0.7445,  0.4662,  1.3040,  0.1835,  0.4798,
#         -0.0431,  0.1115, -0.0826, -0.4685, -0.0110, -0.4125,  0.0064,  0.3704],
#        device='cuda:0')
# None
# end tensor([ 0.3369,  0.9983, -0.1620, -0.7444,  0.4663,  1.3041,  0.1834,  0.4797,
#         -0.0431,  0.1115, -0.0827, -0.4684, -0.0111, -0.4124,  0.0065,  0.3704],
#        device='cuda:0')
# start tensor([ 0.3369,  0.9983, -0.1620, -0.7444,  0.4663,  1.3041,  0.1834,  0.4797,
#         -0.0431,  0.1115, -0.0827, -0.4684, -0.0111, -0.4124,  0.0065,  0.3704],
#        device='cuda:0')
# None
# end tensor([ 0.3370,  0.9982, -0.1619, -0.7444,  0.4663,  1.3042,  0.1834,  0.4796,
#         -0.0432,  0.1116, -0.0827, -0.4683, -0.0111, -0.4124,  0.0065,  0.3705],
#        device='cuda:0')
# start tensor([ 0.3370,  0.9982, -0.1619, -0.7444,  0.4663,  1.3042,  0.1834,  0.4796,
#         -0.0432,  0.1116, -0.0827, -0.4683, -0.0111, -0.4124,  0.0065,  0.3705],
#        device='cuda:0')
# None
# end tensor([ 0.3370,  0.9982, -0.1618, -0.7443,  0.4664,  1.3042,  0.1833,  0.4796,
#         -0.0432,  0.1116, -0.0828, -0.4683, -0.0112, -0.4123,  0.0066,  0.3705],
#        device='cuda:0')
# start tensor([ 0.3370,  0.9982, -0.1618, -0.7443,  0.4664,  1.3042,  0.1833,  0.4796,
#         -0.0432,  0.1116, -0.0828, -0.4683, -0.0112, -0.4123,  0.0066,  0.3705],
#        device='cuda:0')
# None
# end tensor([ 0.3371,  0.9981, -0.1618, -0.7443,  0.4664,  1.3043,  0.1832,  0.4795,
#         -0.0433,  0.1117, -0.0828, -0.4682, -0.0112, -0.4122,  0.0066,  0.3706],
#        device='cuda:0')
# start tensor([ 0.3371,  0.9981, -0.1618, -0.7443,  0.4664,  1.3043,  0.1832,  0.4795,
#         -0.0433,  0.1117, -0.0828, -0.4682, -0.0112, -0.4122,  0.0066,  0.3706],
#        device='cuda:0')
# None
# end tensor([ 0.3371,  0.9981, -0.1618, -0.7442,  0.4665,  1.3043,  0.1832,  0.4795,
#         -0.0433,  0.1117, -0.0828, -0.4682, -0.0113, -0.4122,  0.0067,  0.3706],
#        device='cuda:0')
# [40/15000], training loss: 0.1070
# model saved to ../results/AVD/AVD_Home_004_1_traj1/model_best.pth
# 16
# ^C
# Traceback (most recent call last):
#   File "eval_vis_AVD.py", line 35, in <module>
#     dataset = AVD(data_dir,traj,subsample_rate)
#   File "../dataset_loader/AVD.py", line 47, in __init__
#     current_point_cloud = utils.convert_depth_map_to_pc(depth_map,self.focal_len,self.principal_pt,depth_scale=self.depth_scale)
#   File "../utils/geometry_utils.py", line 319, in convert_depth_map_to_pc
#     c,r = np.meshgrid(range(1,w+1), range(1,h+1))
#   File "/home/mmvc/.conda/envs/ys/lib/python3.6/site-packages/numpy/lib/function_base.py", line 4211, in meshgrid
#     output = [x.copy() for x in output]
#   File "/home/mmvc/.conda/envs/ys/lib/python3.6/site-packages/numpy/lib/function_base.py", line 4211, in <listcomp>
#     output = [x.copy() for x in output]
# KeyboardInterrupt

# %%
# !./lstm_run_train_AVD.sh 2

# %%
# !./lstm_run_train_AVD.sh 3

# %%
# !./lstm_run_train_AVD.sh 4

# %%
# !./lstm_run_train_AVD.sh 5

# %%
# !./lstm_run_train_AVD.sh 6

# %%
# !./lstm_run_train_AVD.sh 7

# %%
# !./lstm_run_train_AVD.sh 8

# %%
# !./lstm_run_train_AVD.sh 9

# %%
# !./lstm_run_train_AVD.sh 10

# %%
# !./lstm_run_train_AVD.sh 11

# %%
# !./lstm_run_train_AVD.sh 12

# %%
# !./lstm_run_train_AVD.sh 13

# %%
# !./lstm_run_train_AVD.sh 14
