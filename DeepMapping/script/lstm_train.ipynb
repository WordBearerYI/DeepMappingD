# %%
# !nvidia-smi
# Out:
# Mon Nov  4 19:42:20 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.56       Driver Version: 418.56       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1080    Off  | 00000000:19:00.0 Off |                  N/A |
# | 47%   70C    P2    57W / 180W |   1132MiB /  8119MiB |     91%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  Off  | 00000000:1A:00.0 Off |                  N/A |
# | 39%   68C    P0     1W / 250W |      0MiB / 10989MiB |      0%      Default |
# ...

# %%
# !./lstm_run_train_2D.sh v1_pose1
# Out:
# ../data/2D/v1_pose1
# LSTM Namespace(batch_size=128, data_dir='../data/2D/v1_pose1', init=None, lat_size=16, log_interval=1, loss='bce_ch', lr=0.0001, model=None, n_epochs=10000, n_samples=19, name='v1_pose1')
# creating model
# start training
# [1/10000], training loss: 4.3631
# model saved to ../results/2D/lstm_v1_pose1/model_best.pth
# [2/10000], training loss: 3.1660
# model saved to ../results/2D/lstm_v1_pose1/model_best.pth
# [3/10000], training loss: 2.8382
# model saved to ../results/2D/lstm_v1_pose1/model_best.pth
# [4/10000], training loss: 2.6877
# model saved to ../results/2D/lstm_v1_pose1/model_best.pth
# [5/10000], training loss: 2.6125
# model saved to ../results/2D/lstm_v1_pose1/model_best.pth
# v1_pose1, ate: 163.37877866671232
# [6/10000], training loss: 2.5568
# model saved to ../results/2D/lstm_v1_pose1/model_best.pth
# [7/10000], training loss: 2.5346
# model saved to ../results/2D/lstm_v1_pose1/model_best.pth
# [8/10000], training loss: 2.5110
# ...

# %%
# !./lstm_run_train_2D.sh v1_pose2

# %%
# !./lstm_run_train_2D.sh v1_pose3

# %%
# !./lstm_run_train_2D.sh v1_pose4

# %%
# !./lstm_run_train_2D.sh v1_pose5

# %%
# !./lstm_run_train_2D.sh v1_pose6

# %%
# !./lstm_run_train_2D.sh v1_pose7
# Out:
# ../data/2D/v1_pose7
# LSTM Namespace(batch_size=128, data_dir='../data/2D/v1_pose7', init=None, lat_size=12, log_interval=10, loss='bce_ch', lr=0.0001, model=None, n_epochs=2000, n_samples=19, name='v1_pose7')
# creating model
# start training
# [10/2000], training loss: 2.7265
# model saved to ../results/2D/lstm_v1_pose7/model_best.pth
# [20/2000], training loss: 2.5962
# model saved to ../results/2D/lstm_v1_pose7/model_best.pth
# [30/2000], training loss: 2.5439
# model saved to ../results/2D/lstm_v1_pose7/model_best.pth
# [40/2000], training loss: 2.5053
# model saved to ../results/2D/lstm_v1_pose7/model_best.pth
# [50/2000], training loss: 2.4832
# model saved to ../results/2D/lstm_v1_pose7/model_best.pth
# v1_pose7, ate: 288.0387909480238
# [60/2000], training loss: 2.4464
# model saved to ../results/2D/lstm_v1_pose7/model_best.pth
# [70/2000], training loss: 0.0392
# model saved to ../results/2D/lstm_v1_pose7/model_best.pth
# [80/2000], training loss: 0.0383
# ...

# %%
python lstm_train_2D.py --lat_size ${LAT_SIZE} --name $NAME -d $DATA_DIR -e $EPOCH -b $BS -l $LOSS -n $N --log_interval $LOG

# !./lstm_run_train_2D.sh v1_pose8

# %%
# !./lstm_run_train_2D.sh v1_pose9

# %%
# !./lstm_run_train_2D.sh v1_pose10

# %%
# !./lstm_run_train_2D.sh v2_pose0 --lr=0.008 --epochs 2000
# Out:
# ../data/2D/v2_pose0
# LSTM Namespace(batch_size=128, data_dir='../data/2D/v2_pose0', init=None, lat_size=12, log_interval=10, loss='bce_ch', lr=0.0001, model=None, n_epochs=2000, n_samples=19, name='v2_pose0')
# creating model
# start training
# [10/2000], training loss: 1.9208
# model saved to ../results/2D/lstm_v2_pose0/model_best.pth
# [20/2000], training loss: 1.8894
# model saved to ../results/2D/lstm_v2_pose0/model_best.pth
# [30/2000], training loss: 1.8662
# model saved to ../results/2D/lstm_v2_pose0/model_best.pth
# [40/2000], training loss: 1.8519
# model saved to ../results/2D/lstm_v2_pose0/model_best.pth
# [50/2000], training loss: 1.8287
# model saved to ../results/2D/lstm_v2_pose0/model_best.pth
# v2_pose0, ate: 10.404990175576364
# [60/2000], training loss: 1.8026
# model saved to ../results/2D/lstm_v2_pose0/model_best.pth
# [70/2000], training loss: 0.0285
# model saved to ../results/2D/lstm_v2_pose0/model_best.pth
# [80/2000], training loss: 0.0279
# ...

# %%
# !./lstm_run_train_2D.sh v2_pose1

# %%
# !./lstm_run_train_2D.sh v2_pose2

# %%
# !./lstm_run_train_2D.sh v2_pose3

# %%
# !./lstm_run_train_2D.sh v2_pose4 --lr=0.008 --epochs 1200
# Out:
# ../data/2D/v2_pose4
# LSTM Namespace(batch_size=128, data_dir='../data/2D/v2_pose4', init=None, lat_size=12, log_interval=10, loss='bce_ch', lr=0.0001, model=None, n_epochs=2000, n_samples=19, name='v2_pose4')
# creating model
# start training
# [10/2000], training loss: 2.2726
# model saved to ../results/2D/lstm_v2_pose4/model_best.pth
# [20/2000], training loss: 2.2178
# model saved to ../results/2D/lstm_v2_pose4/model_best.pth
# [30/2000], training loss: 2.1826
# model saved to ../results/2D/lstm_v2_pose4/model_best.pth
# [40/2000], training loss: 2.1167
# model saved to ../results/2D/lstm_v2_pose4/model_best.pth
# [50/2000], training loss: 2.0775
# model saved to ../results/2D/lstm_v2_pose4/model_best.pth
# v2_pose4, ate: 10.121617524918205
# [60/2000], training loss: 2.0176
# model saved to ../results/2D/lstm_v2_pose4/model_best.pth
# [70/2000], training loss: 0.0314
# model saved to ../results/2D/lstm_v2_pose4/model_best.pth
# [80/2000], training loss: 0.0326
# ...

# %%
# !./lstm_run_train_2D.sh v3_pose0

# %%
# !./lstm_run_train_2D.sh v3_pose1
# Out:
# ../data/2D/v3_pose1
# LSTM Namespace(batch_size=128, data_dir='../data/2D/v3_pose1', init=None, lat_size=12, log_interval=10, loss='bce_ch', lr=0.001, model=None, n_epochs=10000, n_samples=19, name='v3_pose1')
# creating model
# start training
# [10/10000], training loss: 2.0479
# model saved to ../results/2D/lstm_v3_pose1/model_best.pth
# [20/10000], training loss: 1.8549
# model saved to ../results/2D/lstm_v3_pose1/model_best.pth
# [30/10000], training loss: 1.8369
# model saved to ../results/2D/lstm_v3_pose1/model_best.pth
# [40/10000], training loss: 1.8489
# model saved to ../results/2D/lstm_v3_pose1/model_best.pth
# [50/10000], training loss: 1.8801
# model saved to ../results/2D/lstm_v3_pose1/model_best.pth
# v3_pose1, ate: 22.111502519004524
# [60/10000], training loss: 0.0319
# model saved to ../results/2D/lstm_v3_pose1/model_best.pth
# [70/10000], training loss: 0.0296
# model saved to ../results/2D/lstm_v3_pose1/model_best.pth
# [80/10000], training loss: 0.0296
# ...

# %%
# !./lstm_run_train_2D.sh v3_pose2 --lr=0.008 --epochs 1200
# Out:
# ../data/2D/v3_pose2
# LSTM Namespace(batch_size=128, data_dir='../data/2D/v3_pose2', init=None, lat_size=12, log_interval=10, loss='bce_ch', lr=0.0001, model=None, n_epochs=2000, n_samples=19, name='v3_pose2')
# creating model
# start training
# [10/2000], training loss: 2.5870
# model saved to ../results/2D/lstm_v3_pose2/model_best.pth
# [20/2000], training loss: 2.4620
# model saved to ../results/2D/lstm_v3_pose2/model_best.pth
# [30/2000], training loss: 2.3976
# model saved to ../results/2D/lstm_v3_pose2/model_best.pth
# [40/2000], training loss: 2.3343
# model saved to ../results/2D/lstm_v3_pose2/model_best.pth
# [50/2000], training loss: 2.3383
# model saved to ../results/2D/lstm_v3_pose2/model_best.pth
# v3_pose2, ate: 21.049904201550813
# [60/2000], training loss: 2.3115
# model saved to ../results/2D/lstm_v3_pose2/model_best.pth
# [70/2000], training loss: 0.0397
# model saved to ../results/2D/lstm_v3_pose2/model_best.pth
# [80/2000], training loss: 0.0382
# ...

# %%
# !./lstm_run_train_2D.sh v3_pose3
# Out:
# ../data/2D/v3_pose3
# LSTM Namespace(batch_size=128, data_dir='../data/2D/v3_pose3', init=None, lat_size=12, log_interval=10, loss='bce_ch', lr=0.0001, model=None, n_epochs=2000, n_samples=19, name='v3_pose3')
# creating model
# start training
# [10/2000], training loss: 2.3588
# model saved to ../results/2D/lstm_v3_pose3/model_best.pth
# [20/2000], training loss: 2.2813
# model saved to ../results/2D/lstm_v3_pose3/model_best.pth
# [30/2000], training loss: 2.2327
# model saved to ../results/2D/lstm_v3_pose3/model_best.pth
# [40/2000], training loss: 2.2216
# model saved to ../results/2D/lstm_v3_pose3/model_best.pth
# [50/2000], training loss: 2.2384
# model saved to ../results/2D/lstm_v3_pose3/model_best.pth
# v3_pose3, ate: 66.53107942395437
# [60/2000], training loss: 2.1967
# model saved to ../results/2D/lstm_v3_pose3/model_best.pth
# [70/2000], training loss: 0.0357
# model saved to ../results/2D/lstm_v3_pose3/model_best.pth
# [80/2000], training loss: 0.0351
# ...

# %%
# !./lstm_run_train_2D.sh v3_pose4

# %%
# !./lstm_run_train_2D.sh v3_pose5
