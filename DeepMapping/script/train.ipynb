# %%
# !./run_train_2D.sh v1_pose1
# Out:
# ../data/2D/v1_pose1
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0729
# model saved to ../results/2D/v1_pose1/model_best.pth
# [40/3500], training loss: 0.0669
# model saved to ../results/2D/v1_pose1/model_best.pth
# [60/3500], training loss: 0.0633
# model saved to ../results/2D/v1_pose1/model_best.pth
# [80/3500], training loss: 0.0607
# model saved to ../results/2D/v1_pose1/model_best.pth
# v1_pose1, ate: 368.43692268872536
# [100/3500], training loss: 0.0587
# model saved to ../results/2D/v1_pose1/model_best.pth
# [120/3500], training loss: 0.0575
# model saved to ../results/2D/v1_pose1/model_best.pth
# [140/3500], training loss: 0.0565
# model saved to ../results/2D/v1_pose1/model_best.pth
# [160/3500], training loss: 0.0550
# model saved to ../results/2D/v1_pose1/model_best.pth
# v1_pose1, ate: 361.6219461841944
# [180/3500], training loss: 0.0530
# model saved to ../results/2D/v1_pose1/model_best.pth
# [200/3500], training loss: 0.0522
# ...

# %%
# !./run_train_2D.sh v1_pose2
# Out:
# ../data/2D/v1_pose2
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0528
# model saved to ../results/2D/v1_pose2/model_best.pth
# [40/3500], training loss: 0.0471
# model saved to ../results/2D/v1_pose2/model_best.pth
# [60/3500], training loss: 0.0449
# model saved to ../results/2D/v1_pose2/model_best.pth
# [80/3500], training loss: 0.0432
# model saved to ../results/2D/v1_pose2/model_best.pth
# v1_pose2, ate: 188.23331091810877
# [100/3500], training loss: 0.0425
# model saved to ../results/2D/v1_pose2/model_best.pth
# [120/3500], training loss: 0.0423
# model saved to ../results/2D/v1_pose2/model_best.pth
# [140/3500], training loss: 0.0409
# model saved to ../results/2D/v1_pose2/model_best.pth
# [160/3500], training loss: 0.0408
# model saved to ../results/2D/v1_pose2/model_best.pth
# v1_pose2, ate: 186.95110904939187
# [180/3500], training loss: 0.0388
# model saved to ../results/2D/v1_pose2/model_best.pth
# [200/3500], training loss: 0.0392
# ...

# %%
# !./run_train_2D.sh v1_pose3
# Out:
# ../data/2D/v1_pose3
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0489
# model saved to ../results/2D/v1_pose3/model_best.pth
# [40/3500], training loss: 0.0448
# model saved to ../results/2D/v1_pose3/model_best.pth
# [60/3500], training loss: 0.0428
# model saved to ../results/2D/v1_pose3/model_best.pth
# [80/3500], training loss: 0.0429
# model saved to ../results/2D/v1_pose3/model_best.pth
# v1_pose3, ate: 336.12460706107197
# [100/3500], training loss: 0.0417
# model saved to ../results/2D/v1_pose3/model_best.pth
# [120/3500], training loss: 0.0426
# model saved to ../results/2D/v1_pose3/model_best.pth
# [140/3500], training loss: 0.0413
# model saved to ../results/2D/v1_pose3/model_best.pth
# [160/3500], training loss: 0.0407
# model saved to ../results/2D/v1_pose3/model_best.pth
# v1_pose3, ate: 319.3900398577125
# [180/3500], training loss: 0.0374
# model saved to ../results/2D/v1_pose3/model_best.pth
# [200/3500], training loss: 0.0391
# ...

# %%
# !./run_train_2D.sh v1_pose4
# Out:
# ../data/2D/v1_pose4
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0417
# model saved to ../results/2D/v1_pose4/model_best.pth
# [40/3500], training loss: 0.0354
# model saved to ../results/2D/v1_pose4/model_best.pth
# [60/3500], training loss: 0.0335
# model saved to ../results/2D/v1_pose4/model_best.pth
# [80/3500], training loss: 0.0331
# model saved to ../results/2D/v1_pose4/model_best.pth
# v1_pose4, ate: 114.13728496704645
# [100/3500], training loss: 0.0326
# model saved to ../results/2D/v1_pose4/model_best.pth
# [120/3500], training loss: 0.0335
# model saved to ../results/2D/v1_pose4/model_best.pth
# [140/3500], training loss: 0.0318
# model saved to ../results/2D/v1_pose4/model_best.pth
# [160/3500], training loss: 0.0329
# model saved to ../results/2D/v1_pose4/model_best.pth
# v1_pose4, ate: 113.06185861488274
# [180/3500], training loss: 0.0294
# model saved to ../results/2D/v1_pose4/model_best.pth
# [200/3500], training loss: 0.0306
# ...

# %%
# !./run_train_2D.sh v1_pose5
# Out:
# ../data/2D/v1_pose5
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0496
# model saved to ../results/2D/v1_pose5/model_best.pth
# [40/3500], training loss: 0.0453
# model saved to ../results/2D/v1_pose5/model_best.pth
# [60/3500], training loss: 0.0432
# model saved to ../results/2D/v1_pose5/model_best.pth
# [80/3500], training loss: 0.0423
# model saved to ../results/2D/v1_pose5/model_best.pth
# v1_pose5, ate: 85.91011590498812
# [100/3500], training loss: 0.0414
# model saved to ../results/2D/v1_pose5/model_best.pth
# [120/3500], training loss: 0.0411
# model saved to ../results/2D/v1_pose5/model_best.pth
# [140/3500], training loss: 0.0390
# model saved to ../results/2D/v1_pose5/model_best.pth
# [160/3500], training loss: 0.0404
# model saved to ../results/2D/v1_pose5/model_best.pth
# v1_pose5, ate: 67.21701291052453
# [180/3500], training loss: 0.0367
# model saved to ../results/2D/v1_pose5/model_best.pth
# [200/3500], training loss: 0.0361
# ...

# %%
# !./run_train_2D.sh v1_pose6
# Out:
# ../data/2D/v1_pose6
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0541
# model saved to ../results/2D/v1_pose6/model_best.pth
# [40/3500], training loss: 0.0494
# model saved to ../results/2D/v1_pose6/model_best.pth
# [60/3500], training loss: 0.0466
# model saved to ../results/2D/v1_pose6/model_best.pth
# [80/3500], training loss: 0.0457
# model saved to ../results/2D/v1_pose6/model_best.pth
# v1_pose6, ate: 209.8534010761952
# [100/3500], training loss: 0.0449
# model saved to ../results/2D/v1_pose6/model_best.pth
# [120/3500], training loss: 0.0445
# model saved to ../results/2D/v1_pose6/model_best.pth
# [140/3500], training loss: 0.0434
# model saved to ../results/2D/v1_pose6/model_best.pth
# [160/3500], training loss: 0.0439
# model saved to ../results/2D/v1_pose6/model_best.pth
# v1_pose6, ate: 208.30939729262434
# [180/3500], training loss: 0.0423
# model saved to ../results/2D/v1_pose6/model_best.pth
# [200/3500], training loss: 0.0420
# ...

# %%
# !./run_train_2D.sh v1_pose7
# Out:
# ../data/2D/v1_pose7
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0784
# model saved to ../results/2D/v1_pose7/model_best.pth
# [40/3500], training loss: 0.0707
# model saved to ../results/2D/v1_pose7/model_best.pth
# [60/3500], training loss: 0.0662
# model saved to ../results/2D/v1_pose7/model_best.pth
# [80/3500], training loss: 0.0643
# model saved to ../results/2D/v1_pose7/model_best.pth
# v1_pose7, ate: 412.6069872729203
# [100/3500], training loss: 0.0631
# model saved to ../results/2D/v1_pose7/model_best.pth
# [120/3500], training loss: 0.0614
# model saved to ../results/2D/v1_pose7/model_best.pth
# [140/3500], training loss: 0.0593
# model saved to ../results/2D/v1_pose7/model_best.pth
# [160/3500], training loss: 0.0594
# model saved to ../results/2D/v1_pose7/model_best.pth
# v1_pose7, ate: 409.29181079887974
# [180/3500], training loss: 0.0557
# model saved to ../results/2D/v1_pose7/model_best.pth
# [200/3500], training loss: 0.0559
# ...

# %%
# !./run_train_2D.sh v1_pose8
# Out:
# ../data/2D/v1_pose8
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0508
# model saved to ../results/2D/v1_pose8/model_best.pth
# [40/3500], training loss: 0.0438
# model saved to ../results/2D/v1_pose8/model_best.pth
# [60/3500], training loss: 0.0405
# model saved to ../results/2D/v1_pose8/model_best.pth
# [80/3500], training loss: 0.0397
# model saved to ../results/2D/v1_pose8/model_best.pth
# v1_pose8, ate: 103.87632777013864
# [100/3500], training loss: 0.0392
# model saved to ../results/2D/v1_pose8/model_best.pth
# [120/3500], training loss: 0.0380
# model saved to ../results/2D/v1_pose8/model_best.pth
# [140/3500], training loss: 0.0374
# model saved to ../results/2D/v1_pose8/model_best.pth
# [160/3500], training loss: 0.0372
# model saved to ../results/2D/v1_pose8/model_best.pth
# v1_pose8, ate: 96.9983262362135
# [180/3500], training loss: 0.0367
# model saved to ../results/2D/v1_pose8/model_best.pth
# [200/3500], training loss: 0.0357
# ...

# %%
# !./run_train_2D.sh v1_pose9
# Out:
# ../data/2D/v1_pose9
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0750
# model saved to ../results/2D/v1_pose9/model_best.pth
# [40/3500], training loss: 0.0487
# model saved to ../results/2D/v1_pose9/model_best.pth
# [60/3500], training loss: 0.0396
# model saved to ../results/2D/v1_pose9/model_best.pth
# [80/3500], training loss: 0.0340
# model saved to ../results/2D/v1_pose9/model_best.pth
# v1_pose9, ate: 30.75598597515831
# [100/3500], training loss: 0.0319
# model saved to ../results/2D/v1_pose9/model_best.pth
# [120/3500], training loss: 0.0300
# model saved to ../results/2D/v1_pose9/model_best.pth
# [140/3500], training loss: 0.0301
# model saved to ../results/2D/v1_pose9/model_best.pth
# [160/3500], training loss: 0.0293
# model saved to ../results/2D/v1_pose9/model_best.pth
# v1_pose9, ate: 26.558712141322236
# [180/3500], training loss: 0.0291
# model saved to ../results/2D/v1_pose9/model_best.pth
# [200/3500], training loss: 0.0287
# ...

# %%
# !./run_train_2D.sh v1_pose10
# Out:
# ../data/2D/v1_pose10
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0919
# model saved to ../results/2D/v1_pose10/model_best.pth
# [40/3500], training loss: 0.0748
# model saved to ../results/2D/v1_pose10/model_best.pth
# [60/3500], training loss: 0.0695
# model saved to ../results/2D/v1_pose10/model_best.pth
# [80/3500], training loss: 0.0627
# model saved to ../results/2D/v1_pose10/model_best.pth
# v1_pose10, ate: 181.45524153780858
# [100/3500], training loss: 0.0581
# model saved to ../results/2D/v1_pose10/model_best.pth
# [120/3500], training loss: 0.0556
# model saved to ../results/2D/v1_pose10/model_best.pth
# [140/3500], training loss: 0.0542
# model saved to ../results/2D/v1_pose10/model_best.pth
# [160/3500], training loss: 0.0568
# model saved to ../results/2D/v1_pose10/model_best.pth
# v1_pose10, ate: 173.05206123122156
# [180/3500], training loss: 0.0521
# model saved to ../results/2D/v1_pose10/model_best.pth
# ...

# %%
# !./run_train_2D.sh v2_pose0
# Out:
# ../data/2D/v2_pose0
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0501
# model saved to ../results/2D/v2_pose0/model_best.pth
# [40/3500], training loss: 0.0448
# model saved to ../results/2D/v2_pose0/model_best.pth
# [60/3500], training loss: 0.0432
# model saved to ../results/2D/v2_pose0/model_best.pth
# [80/3500], training loss: 0.0424
# model saved to ../results/2D/v2_pose0/model_best.pth
# v2_pose0, ate: 216.58527355740165
# [100/3500], training loss: 0.0417
# model saved to ../results/2D/v2_pose0/model_best.pth
# [120/3500], training loss: 0.0416
# model saved to ../results/2D/v2_pose0/model_best.pth
# [140/3500], training loss: 0.0418
# model saved to ../results/2D/v2_pose0/model_best.pth
# [160/3500], training loss: 0.0407
# model saved to ../results/2D/v2_pose0/model_best.pth
# v2_pose0, ate: 213.51953911017017
# [180/3500], training loss: 0.0395
# model saved to ../results/2D/v2_pose0/model_best.pth
# [200/3500], training loss: 0.0397
# ...

# %%
# !./run_train_2D.sh v2_pose1
# Out:
# ../data/2D/v2_pose1
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0406
# model saved to ../results/2D/v2_pose1/model_best.pth
# [40/3500], training loss: 0.0351
# model saved to ../results/2D/v2_pose1/model_best.pth
# [60/3500], training loss: 0.0335
# model saved to ../results/2D/v2_pose1/model_best.pth
# [80/3500], training loss: 0.0333
# model saved to ../results/2D/v2_pose1/model_best.pth
# v2_pose1, ate: 110.72249522664214
# [100/3500], training loss: 0.0327
# model saved to ../results/2D/v2_pose1/model_best.pth
# [120/3500], training loss: 0.0330
# model saved to ../results/2D/v2_pose1/model_best.pth
# [140/3500], training loss: 0.0321
# model saved to ../results/2D/v2_pose1/model_best.pth
# [160/3500], training loss: 0.0326
# model saved to ../results/2D/v2_pose1/model_best.pth
# v2_pose1, ate: 98.29056475293744
# [180/3500], training loss: 0.0307
# model saved to ../results/2D/v2_pose1/model_best.pth
# [200/3500], training loss: 0.0317
# ...

# %%
# !./run_train_2D.sh v2_pose2
# Out:
# ../data/2D/v2_pose2
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0558
# model saved to ../results/2D/v2_pose2/model_best.pth
# [40/3500], training loss: 0.0497
# model saved to ../results/2D/v2_pose2/model_best.pth
# [60/3500], training loss: 0.0476
# model saved to ../results/2D/v2_pose2/model_best.pth
# [80/3500], training loss: 0.0474
# model saved to ../results/2D/v2_pose2/model_best.pth
# v2_pose2, ate: 158.84947195810972
# [100/3500], training loss: 0.0457
# model saved to ../results/2D/v2_pose2/model_best.pth
# [120/3500], training loss: 0.0453
# model saved to ../results/2D/v2_pose2/model_best.pth
# [140/3500], training loss: 0.0445
# model saved to ../results/2D/v2_pose2/model_best.pth
# [160/3500], training loss: 0.0451
# model saved to ../results/2D/v2_pose2/model_best.pth
# v2_pose2, ate: 152.15241054106085
# [180/3500], training loss: 0.0429
# model saved to ../results/2D/v2_pose2/model_best.pth
# [200/3500], training loss: 0.0429
# ...

# %%
# !./run_train_2D.sh v2_pose3
# Out:
# ../data/2D/v2_pose3
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0715
# model saved to ../results/2D/v2_pose3/model_best.pth
# [40/3500], training loss: 0.0647
# model saved to ../results/2D/v2_pose3/model_best.pth
# [60/3500], training loss: 0.0618
# model saved to ../results/2D/v2_pose3/model_best.pth
# [80/3500], training loss: 0.0586
# model saved to ../results/2D/v2_pose3/model_best.pth
# Traceback (most recent call last):
#   File "/home/mmvc/.conda/envs/ys/lib/python3.6/site-packages/scipy/io/matlab/mio.py", line 39, in _open_file
#     return open(file_like, mode), True
# FileNotFoundError: [Errno 2] No such file or directory: '../data/2D/v2_pose3/gt_pose.mat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "eval_2D.py", line 22, in <module>
#     gt_pose = sio.loadmat(gt_file)
# ...

# %%
# !./run_train_2D.sh v2_pose4
# Out:
# ../data/2D/v2_pose4
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0721
# model saved to ../results/2D/v2_pose4/model_best.pth
# [40/3500], training loss: 0.0650
# model saved to ../results/2D/v2_pose4/model_best.pth
# [60/3500], training loss: 0.0629
# model saved to ../results/2D/v2_pose4/model_best.pth
# [80/3500], training loss: 0.0596
# model saved to ../results/2D/v2_pose4/model_best.pth
# v2_pose4, ate: 280.4486694227619
# [100/3500], training loss: 0.0567
# model saved to ../results/2D/v2_pose4/model_best.pth
# [120/3500], training loss: 0.0546
# model saved to ../results/2D/v2_pose4/model_best.pth
# [140/3500], training loss: 0.0534
# model saved to ../results/2D/v2_pose4/model_best.pth
# [160/3500], training loss: 0.0520
# model saved to ../results/2D/v2_pose4/model_best.pth
# v2_pose4, ate: 246.0009439228457
# [180/3500], training loss: 0.0478
# model saved to ../results/2D/v2_pose4/model_best.pth
# [200/3500], training loss: 0.0470
# ...

# %%
# !./run_train_2D.sh v3_pose0
# Out:
# ../data/2D/v3_pose0
#   File "train_2D.py", line 5
#     print = functools.partial(print,flush=True)
#           ^
# SyntaxError: invalid syntax

# %%
# !./run_train_2D.sh v3_pose1
# Out:
# ../data/2D/v3_pose1
# loading dataset
# creating model
# start training
# [20/3500], training loss: 0.0471
# model saved to ../results/2D/v3_pose1/model_best.pth
# [40/3500], training loss: 0.0415
# model saved to ../results/2D/v3_pose1/model_best.pth
# [60/3500], training loss: 0.0397
# model saved to ../results/2D/v3_pose1/model_best.pth
# [80/3500], training loss: 0.0386
# model saved to ../results/2D/v3_pose1/model_best.pth
# v3_pose1, ate: 218.4943060318577
# [100/3500], training loss: 0.0379
# model saved to ../results/2D/v3_pose1/model_best.pth
# [120/3500], training loss: 0.0375
# model saved to ../results/2D/v3_pose1/model_best.pth
# [140/3500], training loss: 0.0368
# model saved to ../results/2D/v3_pose1/model_best.pth
# [160/3500], training loss: 0.0372
# model saved to ../results/2D/v3_pose1/model_best.pth
# v3_pose1, ate: 216.92337880170845
# [180/3500], training loss: 0.0355
# model saved to ../results/2D/v3_pose1/model_best.pth
# [200/3500], training loss: 0.0360
# ...

# %%
# !./run_train_2D.sh v3_pose2

# %%
# !./run_train_2D.sh v3_pose3

# %%
# !./run_train_2D.sh v3_pose4

# %%
# !./run_train_2D.sh v3_pose5
